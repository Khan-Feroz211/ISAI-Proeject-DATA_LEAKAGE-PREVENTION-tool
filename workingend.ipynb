# %% [markdown]
# <a href="https://colab.research.google.com/github/Khan-Feroz211/ISAI-Proeject-DATA_LEAKAGE-PREVENTION-tool/blob/main/workingend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
